# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# # Generate

# %%
filePath = '/Users/yufanwang/Desktop/Study/Project/Data/generate/perp_old/'
files = sorted(os.listdir(filePath))
files
# Out:
# ['full_N1_with_adv_not_removed.txt',
#  'full_N2_with_adv_not_removed.txt',
#  'full_N3_with_adv_not_removed.txt',
#  'full_N4_with_adv_not_removed.txt',
#  'full_N5_with_adv_not_removed.txt',
#  'full_N6_with_adv_not_removed.txt',
#  'full_N7_with_adv_not_removed.txt',
#  'full_N8_with_adv_not_removed.txt',
#  'orig_with_adv_not_removed.txt']

# %%
length = []
zero_edits = []
orig_mean = []
orig_std = []
adv_mean = []
adv_std = []

for file in files:
    if 'orig' in file:
        orig_file = file
print(filePath + '/' + orig_file)
# Orig
f = open(filePath + '/' + orig_file)
lines = f.readlines()[-3:]
length.append(0)
zero_edits.append(float(lines[0][61:].replace('\n','')))
sub_value = lines[1].split(' ')
orig_mean.append(float(sub_value[3].replace('\t','')))
orig_std.append(float(sub_value[5].replace('\n','')))
sub_value = lines[2].split(' ')
adv_mean.append(float(sub_value[3].replace('\t','')))
adv_std.append(float(sub_value[5].replace('\n','')))


for file in files:
    if 'Vyas' in file or 'orig' in file:
        continue
    length.append(int(file[6]))
    f = open(filePath + '/' + file)
    lines = f.readlines()[-3:]
    zero_edits.append(float(lines[0][61:].replace('\n','')))
    sub_value = lines[1].split(' ')
    orig_mean.append(float(sub_value[3].replace('\t','')))
    orig_std.append(float(sub_value[5].replace('\n','')))
    sub_value = lines[2].split(' ')
    adv_mean.append(float(sub_value[3].replace('\t','')))
    adv_std.append(float(sub_value[5].replace('\n','')))

data = {'length':length,
       'zero edit rate':zero_edits,
       'orig mean':orig_mean,
       'orig std':orig_std,
       'adv mean':adv_mean,
       'adv std':adv_std}
df_gen_perp = pd.DataFrame(data)
df_gen_perp
# Out:
# /Users/yufanwang/Desktop/Study/Project/Data/generate/perp_old//orig_with_adv_not_removed.txt
#    length  zero edit rate  orig mean  orig std  adv mean   adv std
# 0       0        0.359181   1.445501  1.718305  0.000000  0.000000
# 1       1        0.398683   1.360644  1.742729  0.025969  0.159073
# 2       2        0.413680   1.351865  1.717679  0.023043  0.152487
# 3       3        0.423189   1.307608  1.693955  0.052670  0.234599
# 4       4        0.429773   1.261156  1.685644  0.053036  0.244448
# 5       5        0.449525   1.208486  1.685169  0.046452  0.236684
# 6       6        0.459034   1.211046  1.700523  0.051939  0.265483
# 7       7        0.464887   1.179225  1.631893  0.051939  0.320437
# 8       8        0.476591   1.119971  1.632394  0.070958  0.350753

# %%
filePath = '/Users/yufanwang/Desktop/Study/Project/Data/generate/attacks/'
files = sorted(os.listdir(filePath))
files
# Out:
# ['full_N1_with_adv_not_removed.txt',
#  'full_N2_with_adv_not_removed.txt',
#  'full_N3_with_adv_not_removed.txt',
#  'full_N4_with_adv_not_removed.txt',
#  'full_N5_with_adv_not_removed.txt',
#  'full_N6_with_adv_not_removed.txt',
#  'full_N7_with_adv_not_removed.txt',
#  'full_N8_with_adv_not_removed.txt',
#  'full_N9_with_adv_not_removed.txt',
#  'orig_with_adv_not_removed.txt']

# %%
length = []
zero_edits = []
orig_mean = []
orig_std = []
adv_mean = []
adv_std = []

for file in files:
    if 'orig' in file:
        orig_file = file
print(filePath + '/' + orig_file)
# Orig
f = open(filePath + '/' + orig_file)
lines = f.readlines()[-3:]
length.append(0)
zero_edits.append(float(lines[0][61:].replace('\n','')))
sub_value = lines[1].split(' ')
orig_mean.append(float(sub_value[3].replace('\t','')))
orig_std.append(float(sub_value[5].replace('\n','')))
sub_value = lines[2].split(' ')
adv_mean.append(float(sub_value[3].replace('\t','')))
adv_std.append(float(sub_value[5].replace('\n','')))


for file in files:
    if 'Vyas' in file or 'orig' in file:
        continue
    length.append(int(file[6]))
    f = open(filePath + '/' + file)
    lines = f.readlines()[-3:]
    zero_edits.append(float(lines[0][61:].replace('\n','')))
    sub_value = lines[1].split(' ')
    orig_mean.append(float(sub_value[3].replace('\t','')))
    orig_std.append(float(sub_value[5].replace('\n','')))
    sub_value = lines[2].split(' ')
    adv_mean.append(float(sub_value[3].replace('\t','')))
    adv_std.append(float(sub_value[5].replace('\n','')))

data = {'length':length,
       'zero edit rate':zero_edits,
       'orig mean':orig_mean,
       'orig std':orig_std,
       'adv mean':adv_mean,
       'adv std':adv_std}
df_gen_att = pd.DataFrame(data)
df_gen_att
# Out:
# /Users/yufanwang/Desktop/Study/Project/Data/generate/attacks//orig_with_adv_not_removed.txt
#    length  zero edit rate  orig mean  orig std  adv mean   adv std
# 0       0        0.359181   1.445501  1.718305  0.000000  0.000000
# 1       1        0.407827   1.306145  1.695516  0.043526  0.204075
# 2       2        0.397220   1.373080  1.683246  0.008778  0.093298
# 3       3        0.406364   1.388442  1.811000  0.023043  0.164046
# 4       4        0.422092   1.323336  1.725826  0.040966  0.215916
# 5       5        0.420995   1.295903  1.706793  0.036576  0.226608
# 6       6        0.433065   1.271763  1.720827  0.065472  0.293409
# 7       7        0.408193   1.325530  1.716270  0.146672  0.399499
# 8       8        0.432699   1.252377  1.716652  0.061083  0.317094
# 9       9        0.440015   1.242502  1.717117  0.061814  0.291703

# %%
import os
filePath = '/Users/yufanwang/Desktop/Study/Project/Data/v003_0.1/perp/vyas'
files = sorted(os.listdir(filePath))
# files.remove('vyas')
# files.remove('.DS_Store')
sorted(files)
# Out:
# ['evade_perp_beam1_N1_with_adv_not_removed.txt',
#  'evade_perp_beam1_N2_with_adv_not_removed.txt',
#  'evade_perp_beam1_N3_with_adv_not_removed.txt',
#  'evade_perp_beam1_N4_with_adv_not_removed.txt',
#  'evade_perp_beam1_N5_with_adv_not_removed.txt',
#  'evade_perp_beam1_N6_with_adv_not_removed.txt',
#  'evade_perp_beam1_N7_with_adv_not_removed.txt',
#  'evade_perp_beam1_N8_with_adv_not_removed.txt',
#  'no_attack.txt']

# %%
length = []
zero_edits = []
# orig_mean = []
# orig_std = []
# adv_mean = []
# adv_std = []

for file in files:
    if 'no_attack' in file:
        orig_file = file
print(filePath + '/' + orig_file)
# Orig
f = open(filePath + '/' + orig_file)
lines = f.readlines()[-3:]
length.append(0)
print(lines[2][61:])
zero_edits.append(float(lines[2][61:].replace('\n','')))
# sub_value = lines[1].split(' ')
# orig_mean.append(float(sub_value[3].replace('\t','')))
# orig_std.append(float(sub_value[5].replace('\n','')))
# sub_value = lines[2].split(' ')
# adv_mean.append(float(sub_value[3].replace('\t','')))
# adv_std.append(float(sub_value[5].replace('\n','')))


for file in files:
    if 'Vyas' in file or 'orig' in file or "no_attack" in file:
        continue
#     print(file[18:])
    length.append(int(file[18]))
    f = open(filePath + '/' + file)
    lines = f.readlines()[-3:]
    zero_edits.append(float(lines[2][61:].replace('\n','')))
#     sub_value = lines[1].split(' ')
#     orig_mean.append(float(sub_value[3].replace('\t','')))
#     orig_std.append(float(sub_value[5].replace('\n','')))
#     sub_value = lines[2].split(' ')
#     adv_mean.append(float(sub_value[3].replace('\t','')))
#     adv_std.append(float(sub_value[5].replace('\n','')))

data = {'length':length,
       'zero edit rate':zero_edits}
#        'orig mean':orig_mean,
#        'orig std':orig_std,
#        'adv mean':adv_mean,
#        'adv std':adv_std}
df_vyas = pd.DataFrame(data)
df_vyas
# Out:
# /Users/yufanwang/Desktop/Study/Project/Data/v003_0.1/perp/vyas/no_attack.txt
# 0.3833211411850768
#    length  zero edit rate
# 0       0        0.383321
# 1       1        0.425018
# 2       2        0.487198
# 3       3        0.512436
# 4       4        0.526701
# 5       5        0.528895
# 6       6        0.555596
# 7       7        0.585589
# 8       8        0.602048

# %%
filePath = '/Users/yufanwang/Desktop/Study/Project/Data/v003_0.1/attacks_perp_old/'
files = sorted(os.listdir(filePath))
# files.remove('vyas')
# files.remove('.DS_Store')
sorted(files)
# Out:
# ['full_N1_with_adv_not_removed.txt',
#  'full_N2_with_adv_not_removed.txt',
#  'full_N3_with_adv_not_removed.txt',
#  'full_N4_with_adv_not_removed.txt',
#  'full_N5_with_adv_not_removed.txt',
#  'full_N6_with_adv_not_removed.txt',
#  'full_N7_with_adv_not_removed.txt',
#  'full_N8_with_adv_not_removed.txt',
#  'orig_with_adv_not_removed.txt']

# %%
length = []
zero_edits = []
orig_mean = []
orig_std = []
adv_mean = []
adv_std = []

for file in files:
    if 'orig' in file:
        orig_file = file
print(filePath + '/' + orig_file)
# Orig
f = open(filePath + '/' + orig_file)
lines = f.readlines()[-3:]
length.append(0)
zero_edits.append(float(lines[0][61:].replace('\n','')))
sub_value = lines[1].split(' ')
orig_mean.append(float(sub_value[3].replace('\t','')))
orig_std.append(float(sub_value[5].replace('\n','')))
sub_value = lines[2].split(' ')
adv_mean.append(float(sub_value[3].replace('\t','')))
adv_std.append(float(sub_value[5].replace('\n','')))


for file in files:
    if 'Vyas' in file or 'orig' in file:
        continue
    length.append(int(file[6]))
    f = open(filePath + '/' + file)
    lines = f.readlines()[-3:]
    zero_edits.append(float(lines[0][61:].replace('\n','')))
    sub_value = lines[1].split(' ')
    orig_mean.append(float(sub_value[3].replace('\t','')))
    orig_std.append(float(sub_value[5].replace('\n','')))
    sub_value = lines[2].split(' ')
    adv_mean.append(float(sub_value[3].replace('\t','')))
    adv_std.append(float(sub_value[5].replace('\n','')))

data = {'length':length,
       'zero edit rate':zero_edits,
       'orig mean':orig_mean,
       'orig std':orig_std,
       'adv mean':adv_mean,
       'adv std':adv_std}
df_old = pd.DataFrame(data)
df_old
# Out:
# /Users/yufanwang/Desktop/Study/Project/Data/v003_0.1/attacks_perp_old//orig_with_adv_not_removed.txt
#    length  zero edit rate  orig mean  orig std  adv mean   adv std
# 0       0        0.377469   1.361375  1.612356  0.000000  0.000000
# 1       1        0.333943   1.328456  1.621192  0.165691  0.371871
# 2       2        0.432334   1.102780  1.480464  0.080102  0.278158
# 3       3        0.430871   1.132772  1.492609  0.066569  0.257975
# 4       4        0.441843   1.140819  1.557154  0.056328  0.239927
# 5       5        0.248720   1.111558  1.532305  0.418800  0.497147
# 6       6        0.459766   1.043892  1.419473  0.063277  0.281164
# 7       7        0.485735   1.040600  1.465357  0.044257  0.266185
# 8       8        0.477323   1.022677  1.451571  0.063643  0.264310

# %%
import matplotlib.pyplot as plt
# from matplotlib.pyplot import MultipleLocator

# x_major_locator=MultipleLocator(5)

fig, ax = plt.subplots(dpi=600,figsize=(6,4))
ax.plot(df_vyas['length'], df_vyas['zero edit rate'], marker='o',markersize=2,label='Gramformer') # 作y1 = x 图，并标记此线名为linear
ax.plot(df_old['length'], df_old['zero edit rate'], marker='o',markersize=2,label='GramAdv') # 作y1 = x 图，并标记此线名为linear
ax.plot(df_gen_perp['length'], df_gen_perp['zero edit rate'], marker='o',markersize=2,label='GramGen') # 作y1 = x 图，并标记此线名为linear

ax.set_xlabel('Length of PEA (T)') #设置x轴名称 x label
ax.set_ylabel('Fraction of samples with zero edits') #设置y轴名称 y label
# ax.set_title('The Effect of Adding Gaussian Noise on Gramformer Model') #设置图名为Simple Plot
ax.legend() #自动检测要在图例中显示的元素，并且显示
# plt.xlim((0, 15))
# ax.xaxis.set_major_locator(x_major_locator)
plt.show() #图形可视化

# %%
import matplotlib.pyplot as plt
# from matplotlib.pyplot import MultipleLocator

# x_major_locator=MultipleLocator(5)

fig, ax = plt.subplots(dpi=600)
# ax.plot(df_vyas['length'], df_vyas['orig mean'].round(2), marker='o',markersize=2,label='Gramformer Orig') # 作y1 = x 图，并标记此线名为linear
ax.plot(df_old['length'], df_old['orig mean'].round(2), marker='o',markersize=2,label='GramAdv Orig') # 作y1 = x 图，并标记此线名为linear
ax.plot(df_gen_perp['length'], df_gen_perp['orig mean'].round(2), marker='o',markersize=2,label='GramGen Orig') # 作y1 = x 图，并标记此线名为linear

ax.plot(df_old['length'], df_old['adv mean'].round(2), marker='o',markersize=2,label='GramAdv Adv') # 作y1 = x 图，并标记此线名为linear
ax.plot(df_gen_perp['length'], df_gen_perp['adv mean'].round(2), marker='o',markersize=2,label='GramGen Adv') # 作y1 = x 图，并标记此线名为linear

ax.set_xlabel('Length of attacks (T)') #设置x轴名称 x label
ax.set_ylabel('Average edits ') #设置y轴名称 y label
# ax.set_title('The Effect of Adding Gaussian Noise on Gramformer Model') #设置图名为Simple Plot
ax.legend() #自动检测要在图例中显示的元素，并且显示
# plt.xlim((0, 15))
# ax.xaxis.set_major_locator(x_major_locator)
plt.show() #图形可视化
